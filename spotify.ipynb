# %%
# !pip install spotipy

# %%
import spotipy
from spotipy.oauth2 import SpotifyOAuth
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
auth_manager = SpotifyClientCredentials(client_id = 'af74b4d5791b4e7685e0f0b894121b21', client_secret='9103174bfd534e879cdb738fbb821f49')

# %%
spotify = spotipy.Spotify(client_credentials_manager=auth_manager)

# %%
playlist_url = 'https://open.spotify.com/playlist/37i9dQZF1DX4Im4BTs2WMg'

# %%
req_uri = playlist_url.split('/')[4]

# %%
req_uri
# Out:
# '37i9dQZF1DX4Im4BTs2WMg'

# %%
df = spotify.playlist_tracks(req_uri)

# %%
print(df)
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX4Im4BTs2WMg/tracks?offset=0&limit=100&additional_types=track', 'items': [{'added_at': '2024-09-11T04:44:03Z', 'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'}, 'href': 'https://api.spotify.com/v1/users/', 'id': '', 'type': 'user', 'uri': 'spotify:user:'}, 'is_local': False, 'primary_color': None, 'track': {'preview_url': 'https://p.scdn.co/mp3-preview/dd749f561ca535c3a1e3f9e3f716e91a798d878b?cid=af74b4d5791b4e7685e0f0b894121b21', 'available_markets': ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', '
# ...

# %%
df['items']
# Out:
# [{'added_at': '2024-09-11T04:44:03Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': 'https://p.scdn.co/mp3-preview/dd749f561ca535c3a1e3f9e3f716e91a798d878b?cid=af74b4d5791b4e7685e0f0b894121b21',
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
# ...

# %%
df['items'][0]['track']['album']['name']
# Out:
# 'Manasilaayo (From "Vettaiyan")'

# %%
df['items'][0]['track']['album']['id']
# Out:
# '1EWbkJ8zew7sXQnCbKI0Xz'

# %%
df['items'][0]['track']['album']['release_date']
# Out:
# '2024-09-09'

# %%
df['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/1EWbkJ8zew7sXQnCbKI0Xz'

# %%
df['items'][0]['track']['album']['total_tracks']
# Out:
# 1

# %%
album_list=[]
for row in df['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_rel_date = row['track']['album']['release_date']
    album_url = row['track']['album']['external_urls']['spotify']
    album_tot_track = row['track']['album']['total_tracks']
    album_dict = {'Album_ID':album_id, 'Album_Name':album_name, 'Release_Date':album_rel_date, 'URL':album_url, 'Total_Tracks':album_tot_track}
    album_list.append(album_dict)

# %%
album_list
# Out:
# [{'Album_ID': '1EWbkJ8zew7sXQnCbKI0Xz',
#   'Album_Name': 'Manasilaayo (From "Vettaiyan")',
#   'Release_Date': '2024-09-09',
#   'URL': 'https://open.spotify.com/album/1EWbkJ8zew7sXQnCbKI0Xz',
#   'Total_Tracks': 1},
#  {'Album_ID': '5eqQtQhwXiBhZEzrbdDOXQ',
#   'Album_Name': 'Dheema (From "Love Insurance Kompany")',
#   'Release_Date': '2024-10-16',
#   'URL': 'https://open.spotify.com/album/5eqQtQhwXiBhZEzrbdDOXQ',
#   'Total_Tracks': 1},
#  {'Album_ID': '0Wmaf5kSAnQ3hSn09w9BYR',
#   'Album_Name': 'Hey Minnale (From "Amaran") (Tamil)',
#   'Release_Date': '2024-10-04',
#   'URL': 'https://open.spotify.com/album/0Wmaf5kSAnQ3hSn09w9BYR',
#   'Total_Tracks': 1},
#  {'Album_ID': '6Iajx5eba54JLTDf97Me8p',
#   'Album_Name': 'Matta (From "The Greatest Of All Time")',
#   'Release_Date': '2024-08-31',
#   'URL': 'https://open.spotify.com/album/6Iajx5eba54JLTDf97Me8p',
#   'Total_Tracks': 1},
#  {'Album_ID': '4AGLzJHGevDOnuHsQ0gxO5',
#   'Album_Name': 'Aasa Kooda (From "Think Indie")',
# ...

# %%
df['items'][0]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4zCH9qm4R2DADamUHMCa6O'},
#   'href': 'https://api.spotify.com/v1/artists/4zCH9qm4R2DADamUHMCa6O',
#   'id': '4zCH9qm4R2DADamUHMCa6O',
#   'name': 'Anirudh Ravichander',
#   'type': 'artist',
#   'uri': 'spotify:artist:4zCH9qm4R2DADamUHMCa6O'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/0qS0rxCY4YfrUx9GCTlDIW'},
#   'href': 'https://api.spotify.com/v1/artists/0qS0rxCY4YfrUx9GCTlDIW',
#   'id': '0qS0rxCY4YfrUx9GCTlDIW',
#   'name': 'Malaysia Vasudevan',
#   'type': 'artist',
#   'uri': 'spotify:artist:0qS0rxCY4YfrUx9GCTlDIW'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/4PY2xnTu90K0hvkgcljRJl'},
#   'href': 'https://api.spotify.com/v1/artists/4PY2xnTu90K0hvkgcljRJl',
#   'id': '4PY2xnTu90K0hvkgcljRJl',
#   'name': 'Deepthi Suresh',
#   'type': 'artist',
#   'uri': 'spotify:artist:4PY2xnTu90K0hvkgcljRJl'},
# ...

# %%
artist_list=[]
for row in df['items']:
    for key, value in row.items():
        if key == 'track':
            for value in value['artists']:
                artist_dict = {'Artist_ID':value['id'], 'Artist_Name':value['name'], 'URL':value['href']}
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'Artist_ID': '4zCH9qm4R2DADamUHMCa6O',
#   'Artist_Name': 'Anirudh Ravichander',
#   'URL': 'https://api.spotify.com/v1/artists/4zCH9qm4R2DADamUHMCa6O'},
#  {'Artist_ID': '0qS0rxCY4YfrUx9GCTlDIW',
#   'Artist_Name': 'Malaysia Vasudevan',
#   'URL': 'https://api.spotify.com/v1/artists/0qS0rxCY4YfrUx9GCTlDIW'},
#  {'Artist_ID': '4PY2xnTu90K0hvkgcljRJl',
#   'Artist_Name': 'Deepthi Suresh',
#   'URL': 'https://api.spotify.com/v1/artists/4PY2xnTu90K0hvkgcljRJl'},
#  {'Artist_ID': '3UVLcqHc3pOMsWiZv2MeIZ',
#   'Artist_Name': 'Yugendran Vasudevan',
#   'URL': 'https://api.spotify.com/v1/artists/3UVLcqHc3pOMsWiZv2MeIZ'},
#  {'Artist_ID': '4zCH9qm4R2DADamUHMCa6O',
#   'Artist_Name': 'Anirudh Ravichander',
#   'URL': 'https://api.spotify.com/v1/artists/4zCH9qm4R2DADamUHMCa6O'},
#  {'Artist_ID': '5VVN3xZw1i2qihfITZlvCZ',
#   'Artist_Name': 'G. V. Prakash',
#   'URL': 'https://api.spotify.com/v1/artists/5VVN3xZw1i2qihfITZlvCZ'},
#  {'Artist_ID': '1QvyquqkuuwUzdszyoKIy4',
# ...

# %%
df['items'][0]['track']
# Out:
# {'preview_url': 'https://p.scdn.co/mp3-preview/dd749f561ca535c3a1e3f9e3f716e91a798d878b?cid=af74b4d5791b4e7685e0f0b894121b21',
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'BY',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
# ...

# %%
track_list=[]
for row in df['items']:
    track_id = row['track']['id']
    track_name = row['track']['name']
    track_duration = row['track']['duration_ms']
    track_popularity = row['track']['popularity']
    track_url = row['track']['external_urls']['spotify']
    album_id = row['track']['album']['id']
    track_dict = {'Track_ID':track_id, 'Track_Name':track_name, 'Track_Duration':track_duration, 'Track_Popularity':track_popularity, 'Track_URL':track_url, 'Album_ID':album_id}
    track_list.append(track_dict)

# %%
track_list
# Out:
# [{'Track_ID': '7KB0zREYCrQU3refE5x0M3',
#   'Track_Name': 'Manasilaayo (From "Vettaiyan")',
#   'Track_Duration': 235629,
#   'Track_Popularity': 78,
#   'Track_URL': 'https://open.spotify.com/track/7KB0zREYCrQU3refE5x0M3',
#   'Album_ID': '1EWbkJ8zew7sXQnCbKI0Xz'},
#  {'Track_ID': '6CvW7N8JjBHmwEfGz2Yxhk',
#   'Track_Name': 'Dheema (From "Love Insurance Kompany")',
#   'Track_Duration': 235102,
#   'Track_Popularity': 63,
#   'Track_URL': 'https://open.spotify.com/track/6CvW7N8JjBHmwEfGz2Yxhk',
#   'Album_ID': '5eqQtQhwXiBhZEzrbdDOXQ'},
#  {'Track_ID': '1kmJ0EvXClJAt0fSSQLX1m',
#   'Track_Name': 'Hey Minnale (From "Amaran") (Tamil)',
#   'Track_Duration': 229811,
#   'Track_Popularity': 66,
#   'Track_URL': 'https://open.spotify.com/track/1kmJ0EvXClJAt0fSSQLX1m',
#   'Album_ID': '0Wmaf5kSAnQ3hSn09w9BYR'},
#  {'Track_ID': '0xN4nwgOWg59k0t94CJAj4',
#   'Track_Name': 'Matta (From "The Greatest Of All Time")',
#   'Track_Duration': 212090,
#   'Track_Popularity': 73,
# ...

# %%
album_df = pd.DataFrame(album_list)

# %%
artist_df = pd.DataFrame(artist_list)

# %%
track_df = pd.DataFrame(track_list)

# %%
album_df.head()
# Out:
#                  Album_ID                               Album_Name  \
# 0  1EWbkJ8zew7sXQnCbKI0Xz           Manasilaayo (From "Vettaiyan")
# 1  5eqQtQhwXiBhZEzrbdDOXQ   Dheema (From "Love Insurance Kompany")
# 2  0Wmaf5kSAnQ3hSn09w9BYR      Hey Minnale (From "Amaran") (Tamil)
# 3  6Iajx5eba54JLTDf97Me8p  Matta (From "The Greatest Of All Time")
# 4  4AGLzJHGevDOnuHsQ0gxO5          Aasa Kooda (From "Think Indie")
#
#   Release_Date                                                URL  \
# 0   2024-09-09  https://open.spotify.com/album/1EWbkJ8zew7sXQn...
# 1   2024-10-16  https://open.spotify.com/album/5eqQtQhwXiBhZEz...
# 2   2024-10-04  https://open.spotify.com/album/0Wmaf5kSAnQ3hSn...
# 3   2024-08-31  https://open.spotify.com/album/6Iajx5eba54JLTD...
# 4   2024-06-13  https://open.spotify.com/album/4AGLzJHGevDOnuH...
#
#    Total_Tracks
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1

# %%
album_df = album_df.drop_duplicates(subset='Album_ID')

# %%
artist_df = artist_df.drop_duplicates(subset='Artist_ID')

# %%
track_df = track_df.drop_duplicates(subset='Track_ID')

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Album_ID      48 non-null     object
#  1   Album_Name    48 non-null     object
#  2   Release_Date  48 non-null     object
#  3   URL           48 non-null     object
#  4   Total_Tracks  48 non-null     int64
# dtypes: int64(1), object(4)
# memory usage: 2.2+ KB

# %%
artist_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87 entries, 0 to 125
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Artist_ID    87 non-null     object
#  1   Artist_Name  87 non-null     object
#  2   URL          87 non-null     object
# dtypes: object(3)
# memory usage: 2.7+ KB

# %%
track_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Track_ID          50 non-null     object
#  1   Track_Name        50 non-null     object
#  2   Track_Duration    50 non-null     int64
#  3   Track_Popularity  50 non-null     int64
#  4   Track_URL         50 non-null     object
#  5   Album_ID          50 non-null     object
# dtypes: int64(2), object(4)
# memory usage: 2.7+ KB

# %%
album_df['Release_Date'] = pd.to_datetime(album_df['Release_Date'])
